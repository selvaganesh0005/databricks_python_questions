# %%
x='selvaganesh'
y=list(x)
dicy={}
for i in y:
	if i in dicy:
		dicy[i]+=1
	else:
		dicy[i]=1

print(dicy)

# %%
from collections import Counter
# from collections import
h='selvaganesh'
x=Counter(list(h))
print(x)

# %%
# squere

a=[1,2,3,4]
y=10
lambda x: x*x
# print(a)
# print(list(map(lambda x: x*x,a)))
#
squ= lambda x: x*x	

b=squ(y)

print(b)

# %%
r='selvaganesh'
print(list(r).count('s'))
print(r[::-1])
print(r[0:5])
print(len(r))
print(list(r))
print(len(list(r)))
print(''.join(map(lambda x:x+x,list(r)))[::-1])
print('_'.join(set(r)))
print((sorted([((i+i).upper()) for i in r if i!='s'],reverse=True)))

# %%
y=[1,2,3]
x=y
x.remove(1)
print(x)
x.pop(0)
print(x)

print(y)

# %% [markdown]
# ## DataStructures with Shallow Copy ****

# %%
x=[1,2,3]
y=x[:]
y.pop(0)
print(y)
print(x)

# %%
x=[1,2,[1,2],(2,3)]
y=list(x)
y[2].pop(0)
print(y)
print(x)

# %% [markdown]
# ## Deep **Copy**

# %%
import copy
x=[1,3,[1,2],(5,6)]
y=copy.deepcopy(x)
# print(x)
y[2].append(5)
print(y)
print(x)

# %%
# %r
x=['apple','banana','pineapple','orange','apple','pineapple']
a={}
for i in x:
  if i in a:
    a[i]=a[i]+1
  else:
    a[i]=1  
print(a)

# %%
from collections import Counter

b=Counter(x)
for i,j in b.items():
    print(i,j)
print(''.join(b.keys())) 
b.values()

# %% [markdown]
# ## file **handling**

# %%
# read=all the files into single string
# readline=read 1 line of the data
# readlines=read all the lines and keep each line in the list

# %%
with open('/Volumes/my_files/default/vol1/Salary_Data.csv','r') as f:
    f2=f.readlines()
print(f2[0:3])

# %%
with open('/Volumes/my_files/default/vol1/Salary_Data.csv','r') as f:
    f2=f.readline()
print(f2)

# %%
with open('/Volumes/my_files/default/vol1/Salary_Data.csv','r') as f:
    f2=f.read()
print(f2[0])

# %%
# writing 

with open ('/Volumes/my_files/default/vol1/Salary_Data.csv','r') as f1:
    f2=f1.read()
    with open('/Volumes/my_files/default/vol1/new_wite.csv','w') as f3:
        f3.write(f2)

# %%
import csv

# %%
import pandas as pd

df=pd.read_csv('/Volumes/my_files/default/vol1/Salary_Data.csv')
df.head(5)

# %%
df.iloc[0:1]
df.loc[df['Salary']>0,['Salary','YearsExperience']]

# %%
df.to_json('/Volumes/my_files/default/vol1/pd_json.json')
